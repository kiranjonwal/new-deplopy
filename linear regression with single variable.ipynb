# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.show()

# %%
sns.lmplot(x="area", y="price", data=df)
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# **(1) Predict price of a home with area = 3300 sqr ft**

# %%
reg.predict([[3300]])
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
#m
reg.coef_
# Out:
# array([135.78767123])

# %%
#b
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# **Y = m * X + b (m is coefficient and b is intercept)**

# %%
3300*135.78767123 + 180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# **(1) Predict price of a home with area = 5000 sqr ft**

# %%
reg.predict([[5000]])
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
import joblib
joblib.dump(reg,'home_price_model.pkl')
loaded_model=joblib.load('home_price_model.pkl')

# %% [markdown]
# <h3 style="color:purple">Generate CSV file with list of home price predictions</h3>

# %%
area_df = pd.read_csv("areas.csv")
area_df.head(3)

# %%
p = reg.predict(area_df)
p

# %%
area_df['prices']=p
area_df

# %%
area_df.to_csv("prediction1.csv")

# %% [markdown]
# <h3>Exercise</h3>

# %% [markdown]
# 1-  Predict canada's per capita income in year 2020. trainer will provide canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income of canadian citizens in year 2020

# %%
df = pd.read_csv('canada_per_capita_income.csv')
df

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df['per_capita_income_US'])

# %% [markdown]
# <h3>Answer</h3>

# %% [markdown]
# 41288.69409442

# %% [markdown]
# <p >2- Predict Insurence Premium. trainer will provide Insurence.csv file. Using this build a regression model and predict the premium according to age, find out premium of age 21 and 50</p>

# %% [markdown]
# <h3>Answer</h3>

# %% [markdown]
# 13480 and 65100
